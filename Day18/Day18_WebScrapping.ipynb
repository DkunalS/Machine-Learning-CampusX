# %% [markdown]
# <a href="https://colab.research.google.com/github/DkunalS/Machine-Learning-CampusX/blob/main/Day18/Day18_WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpages = requests.get('https://www.meesho.com/ethnicwear-women/pl/3tq', headers=headers).text

# %%
soup = BeautifulSoup(webpages, 'lxml')

# %%
soup.prettify()
df = pd.DataFrame()

# %%
# Fetching name through Scrapping

name = [i.text for i in (soup.find_all('p', class_='sc-eDvSVe gQDOBc NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU'))]
df['name'] = name
df
# Out:
#                                    name
# 0                 Banita Drishya Sarees
# 1             Aagyeyi Attractive Sarees
# 2       Jivika Voguish Women Kurta Sets
# 3                Alisha Superior Sarees
# 4         Chitrarekha Attractive Kurtis
# 5                  Kashvi Petite Sarees
# 6          Stylish Women Abayas & Coats
# 7       Charvi Voguish Women Kurta Sets
# 8               Aishani Graceful Kurtis
# 9                  Trendy Women Blouses
# 10                Classic Women Blouses
# 11          Abhisarika Georgette Sarees
# 12                 Latest Women Blouses
# 13           Abhisarika Alluring Sarees
# 14  Versatile Attractive Women Dupattas
# 15      Banita Voguish Women Kurta Sets
# 16               Myra Attractive Sarees
# 17              Aakarsha Refined Sarees
# 18    Yagnik Fashion Women's Kurta Sets

# %%
# Fetching price through Scrapping
price = [i.text for i in (soup.find_all('h5'))]
df['price'] = price
df['price'] = df['price'].str.replace('₹', '', regex=False)
df
# Out:
#                                    name price
# 0                 Banita Drishya Sarees   477
# 1             Aagyeyi Attractive Sarees   244
# 2       Jivika Voguish Women Kurta Sets   295
# 3                Alisha Superior Sarees  311
# 4         Chitrarekha Attractive Kurtis   215
# 5                  Kashvi Petite Sarees   393
# 6          Stylish Women Abayas & Coats   302
# 7       Charvi Voguish Women Kurta Sets   491
# 8               Aishani Graceful Kurtis  266
# 9                  Trendy Women Blouses  255
# 10                Classic Women Blouses  255
# 11          Abhisarika Georgette Sarees   289
# 12                 Latest Women Blouses  167
# 13           Abhisarika Alluring Sarees   260
# 14  Versatile Attractive Women Dupattas   341
# 15      Banita Voguish Women Kurta Sets  475
# 16               Myra Attractive Sarees  266
# 17              Aakarsha Refined Sarees  462
# 18    Yagnik Fashion Women's Kurta Sets   604

# %%
# Fetching rating through Scrapping
rating = [i.text for i in (soup.find_all('span', class_='sc-eDvSVe laVOtN'))]
df['rating'] = rating
df
# Out:
#                                    name price rating
# 0                 Banita Drishya Sarees   477    4.0
# 1             Aagyeyi Attractive Sarees   244    3.8
# 2       Jivika Voguish Women Kurta Sets   295    3.6
# 3                Alisha Superior Sarees  311     3.8
# 4         Chitrarekha Attractive Kurtis   215    4.0
# 5                  Kashvi Petite Sarees   393    4.2
# 6          Stylish Women Abayas & Coats   302    4.0
# 7       Charvi Voguish Women Kurta Sets   491    4.2
# 8               Aishani Graceful Kurtis  266     3.7
# 9                  Trendy Women Blouses  255     3.7
# 10                Classic Women Blouses  255     3.7
# 11          Abhisarika Georgette Sarees   289    3.9
# 12                 Latest Women Blouses  167     3.8
# 13           Abhisarika Alluring Sarees   260    4.0
# 14  Versatile Attractive Women Dupattas   341    4.5
# 15      Banita Voguish Women Kurta Sets  475     4.1
# 16               Myra Attractive Sarees  266     3.9
# ...

# %%
# Fetching review counting through scrapping
reviews = [i.text for i in (soup.find_all('span', class_='sc-eDvSVe XndEO NewProductCardstyled__RatingCount-sc-6y2tys-22 iaGtYc NewProductCardstyled__RatingCount-sc-6y2tys-22 iaGtYc'))]
df['reviews'] = reviews
df
# Out:
#                                    name price rating         reviews
# 0                 Banita Drishya Sarees   477    4.0     567 Reviews
# 1             Aagyeyi Attractive Sarees   244    3.8   44931 Reviews
# 2       Jivika Voguish Women Kurta Sets   295    3.6  134504 Reviews
# 3                Alisha Superior Sarees  311     3.8      47 Reviews
# 4         Chitrarekha Attractive Kurtis   215    4.0   55198 Reviews
# 5                  Kashvi Petite Sarees   393    4.2      15 Reviews
# 6          Stylish Women Abayas & Coats   302    4.0     450 Reviews
# 7       Charvi Voguish Women Kurta Sets   491    4.2   18730 Reviews
# 8               Aishani Graceful Kurtis  266     3.7   14482 Reviews
# 9                  Trendy Women Blouses  255     3.7    6023 Reviews
# 10                Classic Women Blouses  255     3.7     425 Reviews
# 11          Abhisarika Georgette Sarees   289    3.9   25166 Reviews
# 12                 Latest Women Blouses  167     3.8    1283 Reviews
# ...

# %%
name1 = []

# length = [i.text for i in soup.find_all('div', class_='sc-bcXHqe ProductList__PLPContainer-sc-8lnc8o-1 cppHWG hSZegP')]
# print(len(length))
for i in (soup.find_all('div', class_='sc-bcXHqe ProductList__PLPContainer-sc-8lnc8o-1 cppHWG hSZegP')):
  name1.append(i.find('p', class_='sc-eDvSVe gQDOBc NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU').text)
  print(name1)
all = [i.text for i in (soup.find_all('div', class_='sc-dkrFOg ggMaSF'))]
# all
# Out:
# ['Banita Drishya Sarees']

# %%
# # Fetching review counting through scrapping
# print(len(soup.find_all('div', class_='sc-ftTHYK eHVGcU')))
# # text = [i.text for i in (soup.find_all('div', class_='sc-ftTHYK hqYVzH'))]
# # text
# Out:
# 0
